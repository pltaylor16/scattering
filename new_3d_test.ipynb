# %%
from scatter import Scatter3D
from math import pi as pi
from matplotlib import pyplot as plt
import numpy as np
import tensorflow as tf
# Out:
# 2023-07-27 14:10:25.395071: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
J = 6
L = 4
M = 16
slant1 = 4./L
slant2 = 2./L

S = Scatter3D(J,L,M,slant1, slant2)

# %%
f1 = S.filter_bank()

# %%
f1['psi']
# Out:
# [{'levels': [array([[[ 0.00000000e+00,  5.06317616e-02,  2.21966356e-01, ...,
#              2.89727449e-02, -1.49452686e-03, -8.64946842e-03],
#            [ 2.70721912e-02,  1.58457875e-01,  5.53313136e-01, ...,
#              2.00469494e-02, -4.06217575e-03, -4.52637672e-03],
#            [ 9.02342796e-02,  3.75806093e-01,  1.14096797e+00, ...,
#              1.09221935e-02, -3.29089165e-03,  1.00264549e-02],
#            ...,
#            [ 2.34973133e-02,  2.91070938e-02,  3.21101993e-02, ...,
#              2.89910883e-02,  1.43282712e-02,  1.63263083e-02],
#            [ 6.08682632e-04,  4.60267067e-03,  2.27364302e-02, ...,
#              3.35097462e-02,  7.72675872e-03,  1.22976303e-03],
#            [-6.37054443e-03,  9.40567255e-03,  7.19028115e-02, ...,
#              3.40232253e-02,  2.72291899e-03, -6.32405281e-03]],
#
#           [[ 2.70724297e-02,  1.58458114e-01,  5.53313136e-01, ...,
#              2.00469494e-02, -4.06169891e-03, -4.52589989e-03],
# ...

# %%
np.max(f1['psi'][19])
# Out:
# {'levels': [array([[[ 3.57627869e-07,  1.77626586e+00,  1.19223547e+01, ...,
#            -1.24645233e-03, -1.46787763e-02, -6.23291880e-02],
#           [ 7.25316048e-01,  9.12921906e+00,  3.90693054e+01, ...,
#            -3.09610367e-03, -2.37216353e-02, -4.34485860e-02],
#           [ 3.00634050e+00,  2.28311844e+01,  6.40955200e+01, ...,
#            -3.84140015e-03, -1.69371367e-02,  1.12633556e-01],
#           ...,
#           [-4.72082198e-03, -9.89244040e-03, -2.70226318e-03, ...,
#            -1.25169754e-06, -5.33498824e-05, -8.21440946e-04],
#           [-2.63394751e-02, -2.81231105e-02,  1.20509408e-01, ...,
#            -2.44379044e-05, -6.90430403e-04, -7.01861084e-03],
#           [-6.78906366e-02,  1.15905523e-01,  1.80349851e+00, ...,
#            -2.50577927e-04, -4.50214744e-03, -2.99839601e-02]],
#
#          [[ 7.25314617e-01,  9.12921715e+00,  3.90693054e+01, ...,
#            -3.09896469e-03, -2.37258971e-02, -4.34512831e-02],
# ...

# %% [markdown]
# # Okay now let's compute all the coefficients

# %%
J = 4
L = 4
M = 16
slant1 = 4./L
slant2 = 2./L

S1 = Scatter3D(J,L,M,slant1, slant2)

# %%
#filter_bank = S1.padded_filter_bank()
filter_bank = S1.filter_bank()

# %%
x = tf.ones((32,M,M,M))
phi = filter_bank['phi']
psi = filter_bank['psi']
max_order = 2
coeffs = S1.compute_coefs_no_pad(x, phi, psi, max_order, out_type = 'array')
#coeffs = S1.compute_coefs(x, phi, psi, max_order, out_type = 'array')
# Out:
# 2023-07-27 14:10:39.543208: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Caution: stack may not be doing the right thing!

# %%
print (np.shape(coeffs))
# Out:
# (32, 1, 1601, 1, 1)

# %% [markdown]
# # Debug the padding
